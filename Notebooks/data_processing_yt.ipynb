# %%
import librosa
import librosa.display
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import pickle
import youtube_dl
import webvtt
from pydub import AudioSegment
import datetime
from glob import glob

import gc
import os
# Imports the Google Cloud client library
from google.cloud import speech
from google.cloud.speech import enums
from google.cloud.speech import types

from demonetization import Segment, create_df, generate_segment_list
from data_gathering_functions import rip_video

# %%
# Put in name of json file
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = input()
# Out:
# _alanpersonal-984c98451486.json

# %%
# Instantiates a client
client = speech.SpeechClient()

# %%
def create_output(client, video_type, set_n, label):

    audio_file_type = 'mp3'
    vid_output = f'{video_type}/set{set_n}'
    time_per_segment = 30
    cutoff = 10
    segment_folder = f'{video_type}_segments/set{set_n}'
    seg_list = generate_segment_list(label, audio_file_type, vid_output,
                                     client, time_per_segment, cutoff, segment_folder)
    
    with open(f'output/{video_type}/{video_type}_set{set_n}.pkl', 'wb') as filename:
        pickle.dump(seg_list, filename)
        filename.close()
        
    seg_df = create_df(seg_list)
    seg_df.to_pickle(f'output/{video_type}/{video_type}{set_n}_df.pkl')
    
    del seg_list
    gc.collect()
    
    return f'Finished with {video_type}{set_n}\n\n\n'

# %%
for idx in range(2, 5):
    create_output(client, 'yt', idx, 0)
# Out:
# Found .vtt
# Finished with: yt/set2/How I Manage My Anxiety IN THE MOMENT-Koq_WwRLB2Q.mp3
# Found .vtt
# Finished with: yt/set2/I Almost Died (My Side Of The Story)-05dvHnDhLz0.mp3
# Found .vtt
# Finished with: yt/set2/I Won't Break Up with You BUT You Annoy Me-R9quQpxupqg.mp3
# Found .vtt
# Finished with: yt/set2/How to Dress Like a Lesbian! Feat. Jessica Kellgren-Fozard-h_EF2LkQSJQ.mp3
# Found .vtt
# Finished with: yt/set2/How to avoid getting STI's _ Come Curious-ifj085zjXmI.mp3
# Found .vtt
# Finished with: yt/set2/Insecure Star Dro on His Ho Phase and Happier Sex-U85otqCztz4.mp3
# Found .vtt
# Finished with: yt/set2/I'm Starring in Dodie's Music Video...-F7WM-ug7ihc.mp3
# Found .vtt
# Finished with: yt/set2/Embarrassing Period Stories, Sex & Overflow! _ Q&A with Lia! _ Hannah Witton-Gk6pzIRbAvU.mp3
# Found .vtt
# Finished with: yt/set2/Gay Men French KISS Women For The First Time!!!-9fmGGCWHoZw.mp3
# Found .vtt
# Finished with: yt/set2/I have an Eating Disorder, but I'll be ok 💛 [CC]-jog9mVdc2pE.mp3
# Found .vtt
# Finished with: yt/set2/How to Queef-xFOeQDJjSos.mp3
# Found .vtt
# Finished with: yt/set2/I asked my Corporate Job if I could Wear the Men's Uniform...-SCfdXOl-jVM.mp3
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Finished with: yt/set2/KINKY TRAVEL TIPS-_l5zLosaGbQ.mp3
# Found .vtt
# Finished with: yt/set2/How to have a Successful Holiday Fling _ Hannah Witton-YwlNtzq2k1M.mp3
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Finished with: yt/set2/How to SQUIRT using toys - Squirting Curious-ZmGKprJO6Q0.mp3
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Finished with: yt/set2/HOW TO WORSHIP YOUR WIFE!! (UnBoxing Video)-GpmJxCbFUy0.mp3
# Found .vtt
# Finished with: yt/set2/How to NOT Rape-YRkRS5pvcp0.mp3
# Found .vtt
# Finished with: yt/set2/Having sex at University - UNISEX Curious ad-U2zFDbrYSwI.mp3
# Found .vtt
# Finished with: yt/set2/Horoscopes Aren't Real.-C815z9tKf90.mp3
# Found .vtt
# Finished with: yt/set2/How (some) Asexuals ...Have Sex 👍🏻 [CC]-CbjFK8QDhVM.mp3
# Found .vtt
# Finished with: yt/set2/MY FIRST YEAR AT VIDCON (ft. STEF SANJATI, STEVIE, AARON, AND SO MUCH MORE!!!)-CxjY3gaH6Rk.mp3
# Found .vtt
# Finished with: yt/set2/Let's Talk About Sex Work _ Hannah Witton-5_LtrS-wgEc.mp3
# Found .vtt
# Finished with: yt/set2/Ex Best Friends Talk After 5 Years - Those Girls are Wild-pwby_8-yaK0.mp3
# Found .vtt
# Finished with: yt/set2/HOW TO NOT BE JEALOUS - Lesbian Sex 101 _ Stevie Boebi-2es6-2h2u-Y.mp3
# Found .vtt
# Finished with: yt/set3/Peen Packing, Undies, and Androgyny 😉-rBc9Xb3N0iY.mp3
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Finished with: yt/set3/Sex Toys for Men with Riyadh K! _ Hannah Witton-ISt8FhqHkNA.mp3
# Found .vtt
# Finished with: yt/set3/PORNSTAR REACTS TO DATING APPS-ra3mROf41XQ.mp3
# Found .vtt
# Finished with: yt/set3/PRIDE WAS AMAZING! (ft. MIKE, AJA, ADORE, SHANGELA, TODRICK HALL, DARIENNE, ETC ETC ETCCCC)-Sq3FAA1fOcg.mp3
# Found .vtt
# Finished with: yt/set3/My Wife Almost Died-Bfgf-el38tM.mp3
# Found .vtt
# Finished with: yt/set3/Pulling out & why it doesn't work! _ Come Curious-6xn9leXgccA.mp3
# Found .vtt
# Finished with: yt/set3/Resources for Sex Nerds _ Hannah Witton-ie27o7FGL5U.mp3
# Found .vtt
# Finished with: yt/set3/PROMBOYISH - As We Are by Ari Fitz-c46bAJFbRK0.mp3
# Found .vtt
# Finished with: yt/set3/Picking the Right Lube-5A5Nz_cnyfI.mp3
# Found .vtt
# Finished with: yt/set3/OUR KINKY FAVS - For August-pLZdbENibIk.mp3
# Found .vtt
# Finished with: yt/set3/Open Marriage-mZzCGof8x-M.mp3
# Found .vtt
# Finished with: yt/set3/PROMBOYISH - As We Are by Ari Fitz (WATCH ON YOUR PHONE  -)-FVTqqBKURd0.mp3
# Found .vtt
# Finished with: yt/set3/The Benefits of Porn _ Hannah Witton-eh2-_u76RIw.mp3
# Found .vtt
# Finished with: yt/set3/Sex with a Stoma _ Hannah Witton-SSYdKcXj3GM.mp3
# Found .vtt
# Finished with: yt/set3/PERIOD SEX-vi6gDyuhL1Q.mp3
# Found .vtt
# Finished with: yt/set3/Our Sex After Trauma! (THE TRUTH)-XFr2m5igA9s.mp3
# Found .vtt
# Finished with: yt/set3/The History of Condoms in 60 Seconds _ Hannah Witton _ ad-fU23oygJToc.mp3
# Found .vtt
# Finished with: yt/set3/My Wife is not a Girl (and I'll always love them 💕) [CC]-bQEg_gNzuvs.mp3
# Found .vtt
# Finished with: yt/set3/POTTER WIZARDING WORLD MEETS PRIDE - LA Travel Vlog Pt2!-wt93Rb300qA.mp3
# Found .vtt
# Finished with: yt/set3/The Imperfect Way I Got ENGAGED!-nU42WiyL-dU.mp3
# Found .vtt
# Finished with: yt/set3/Queer, Asexual, and Gender Spectrums!-wV0vQPE_qyk.mp3
# Found .vtt
# Finished with: yt/set4/🌼 Why I'm Not a Boy 🌼-6EDzapkuN34.mp3
# Found .vtt
# Finished with: yt/set4/Why I Won't Get Back Together With My Ex.-wv28xqAoYuc.mp3
# Found .vtt
# Finished with: yt/set4/TRANS WOMEN ARE WOMEN - Controversial Lesbians React to TERFS-a-7xgcPlFxE.mp3
# Found .vtt
# Finished with: yt/set4/WHAT DID I GET-KVEZIYKBfCI.mp3
# Found .vtt
# Finished with: yt/set4/The REAL Reason We're Getting Married-hhKKFs7MsOo.mp3
# Found .vtt
# Finished with: yt/set4/Turning me HIGH FEMME 💋💋💋 [CC]-cs9ojS2dp4U.mp3
# Found .vtt
# Finished with: yt/set4/WE GOT MARRIED!!! (Our Ceremony)-Le6TpQApD5s.mp3
# Found .vtt
# Finished with: yt/set4/TPOC BINDER GIVEAWAY!!!!-OdK7yDAN8VA.mp3
# Found .vtt
# Finished with: yt/set4/Why I'm Sex Positive _ Hannah Witton-UIryPecVFyU.mp3
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Finished with: yt/set4/Toys to give you clitorally spectacular orgasms! Ad-6ZddQUoABHs.mp3
# Found .vtt
# Finished with: yt/set4/Wanna Meet My Mom-UyEGDv7WYnI.mp3
# Found .vtt
# Finished with: yt/set4/Why we started our channel + Q&A _ Come Curious-Ts_J7Iw6wD8.mp3
# Found .vtt
# Finished with: yt/set4/Why Sex Hurts-Dx9DVFSNx7Q.mp3
# Found .vtt
# Finished with: yt/set4/WE ARE GROWING OUR FAMILY...!!!!-KhCZLJK_ltY.mp3
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Finished with: yt/set4/Vagina and Vulva Hygiene-m5ScLYVf644.mp3
# Found .vtt
# Finished with: yt/set4/Why I Unfollowed Everyone on Instagram (AGAIN)-xlUUb7tZPbg.mp3
# Found .vtt
# Finished with: yt/set4/WRIST TO ANKLE TIE-18jsjlzwhtE.mp3
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Finished with: yt/set4/What's the A Spot-fEjFHUOo8_U.mp3
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Finished with: yt/set4/WHY DID I AGREE TO THIS UNBOXING WITH STEP MOM [ft. Mike]-oZgq6JouCZc.mp3
# Found .vtt
# Finished with: yt/set4/✨I Got Top Surgery!! ✨-59jnV_15vSM.mp3
# Found .vtt
# Finished with: yt/set4/What is BIG dick energy _ Come Curious-iTdqISIxCNU.mp3
# Found .vtt
# Finished with: yt/set4/WHAT'S A COCKRING FOR-qFdZ8lfI830.mp3
# Found .vtt
# Finished with: yt/set4/Why I'm NOT Sex Positive _ Hannah Witton-QGSZV1KN5eA.mp3
# Found .vtt
# Finished with: yt/set4/Why My Relationships Keep Failing!-vlgs5zcqTyo.mp3
# Found .vtt
# Finished with: yt/set4/TRANS PRIDE PLUG REVIEW-INW2KNbCUt4.mp3
# Found .vtt
# Finished with: yt/set4/What To Do If Your Crush Doesn't Like You...-DBpJiENsF-Q.mp3
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Used google cloud
# Finished with: yt/set4/TOP 5 LESBIAN YOUTUBERS I HAVE A CRUSH ON-QLB1sG-3FjQ.mp3
# Found .vtt
# Finished with: yt/set4/Working in Porn with Erika Lust-lCO0pb04DaE.mp3
# Found .vtt
# Finished with: yt/set4/Yeast Infections 101-TFyEjchfHGo.mp3
